# %% [markdown]
# Import data sets

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

raw_reservoir = pd.read_csv(os.path.join('data_in', 'raw_708reservoir.csv'))
raw_reservoir_ts = pd.read_csv(os.path.join('data_in', 'raw_708reservoir_timeseries_snowice_removed.csv'))

# %%
raw_reservoir.shape
# Out:
# (707, 600)

# %%
# any columns all zeroes?
sum(raw_reservoir.sum(axis=0) == 0)
# Out:
# 14

# %%
raw_reservoir.dtypes
# Out:
# COMID                              int64
# Name                              object
# MaxAreaLowIntensityBloom           int64
# MaxAreaModerateIntensityBloom      int64
# MaxAreaHighIntensityBloom          int64
# MaxCyanConcentration             float64
# COUNT                              int64
# AREA                             float64
# Freq                             float64
# AgMidHiSlo                         int64
# CatAreaSqK                       float64
# WsAreaSqKm                       float64
# CatPctFull                       float64
# WsPctFull                        float64
# inStreamCa                         int64
# PctAg2006S                       float64
# PctAg200_1                       float64
# PctAg200_2                       float64
# PctAg200_3                       float64
# Agricultur                         int64
# CBNFCat                          float64
# FertCat                          float64
# ManureCat                        float64
# ...

# %%
raw_reservoir.head
# Out:
# <bound method NDFrame.head of          COMID                                               Name  \
# 0        11646                              Boyd Lake,  Boyd Lake
# 1        11816          Carter Lake Reservoir,  Carter Lake Dam 1
# 2       187905              Marston Lake,  Marston Lake North Dam
# 3       188031                     Chatfield Lake,  Chatfield Dam
# 4       204341          Unit Number Two,  Delta Lake Unit 2 Levee
# 5       224233                   Jackson Reservoir,  Jackson Lake
# 6       224311                    Riverside Reservoir,  Riverside
# 7       224443                          Empire Reservoir,  Empire
# 8       224573                     Milton Reservoir,  Milton Lake
# 9       228235                      Standley Lake,  Standley Lake
# 10      228919                              Barr Lake,  Barr Lake
# 11      229217               Cherry Creek Lake,  Cherry Creek Dam
# 12      253350                               Lake Hefner,  Hefner
# ...

# %%
raw_reservoir_ts.shape
# Out:
# (145848, 9)

# %%
raw_reservoir_ts.dtypes
# Out:
# COMID                     int64
# cyan_high_extent        float64
# cyan_moderate_extent    float64
# cyan_low_extent         float64
# cyan_max                float64
# start_date               object
# year                      int64
# month                     int64
# day                       int64
# dtype: object

# %%
raw_reservoir_ts.head
# Out:
# <bound method NDFrame.head of           COMID  cyan_high_extent  cyan_moderate_extent  cyan_low_extent  \
# 0       2678978               0.0                   0.0              0.0
# 1       2678978               NaN                   NaN              NaN
# 2       2678978               NaN                   NaN              NaN
# 3       2678978               0.0                   0.0              0.0
# 4       2678978               NaN                   NaN              NaN
# 5       2678978               0.0                   0.0              0.0
# 6       2678978               NaN                   NaN              NaN
# 7       2678978               NaN                   NaN              NaN
# 8       2678978               0.0                   0.0              0.0
# 9       2678978               0.0                   0.0              0.0
# 10      2678978               NaN                   NaN              NaN
# ...
